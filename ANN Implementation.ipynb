# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
data = pd.read_csv("Churn_Modelling.csv")

# %%
X = data.iloc[:, 3: -1].values
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
Y = data.iloc[:, -1].values

# %%
from sklearn.preprocessing import LabelEncoder
LE1 = LabelEncoder()
X[:,2] = np.array(LE1.fit_transform(X[:,2]))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct =  ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder = "passthrough")
X = np.array(ct.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
ann.fit(X_train, Y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 3s 4ms/step - loss: 0.6355 - accuracy: 0.6635
# Epoch 2/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4710 - accuracy: 0.7936
# Epoch 3/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4406 - accuracy: 0.8009
# Epoch 4/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4226 - accuracy: 0.8099
# Epoch 5/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4096 - accuracy: 0.8194
# Epoch 6/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3996 - accuracy: 0.8286
# Epoch 7/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3909 - accuracy: 0.8316
# Epoch 8/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3839 - accuracy: 0.8367
# Epoch 9/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3770 - accuracy: 0.8399
# Epoch 10/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3712 - accuracy: 0.8445
# Epoch 11/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3667 - accuracy: 0.8457
# Epoch 12/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3623 - accuracy: 0.8499
# Epoch 13/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3595 - accuracy: 0.8503
# Epoch 14/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3570 - accuracy: 0.8535
# Epoch 15/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3549 - accuracy: 0.8550
# Epoch 16/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3529 - accuracy: 0.8541
# Epoch 17/100
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3510 - accuracy: 0.8556
# Epoch 18/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3500 - accuracy: 0.8574
# Epoch 19/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3490 - accuracy: 0.8585
# Epoch 20/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3482 - accuracy: 0.8570
# Epoch 21/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3472 - accuracy: 0.8566
# Epoch 22/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3466 - accuracy: 0.8591
# Epoch 23/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3459 - accuracy: 0.8579
# Epoch 24/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3451 - accuracy: 0.8589
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3448 - accuracy: 0.8593
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3444 - accuracy: 0.8601
# Epoch 27/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3442 - accuracy: 0.8611
# Epoch 28/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3435 - accuracy: 0.8595
# Epoch 29/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3435 - accuracy: 0.8605
# Epoch 30/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3425 - accuracy: 0.8612
# Epoch 31/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3423 - accuracy: 0.8611
# Epoch 32/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3422 - accuracy: 0.8620
# Epoch 33/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3418 - accuracy: 0.8608
# Epoch 34/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3414 - accuracy: 0.8610
# Epoch 35/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3413 - accuracy: 0.8602
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3411 - accuracy: 0.8602
# Epoch 37/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3404 - accuracy: 0.8633
# Epoch 38/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3404 - accuracy: 0.8605
# Epoch 39/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3396 - accuracy: 0.8619
# Epoch 40/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3400 - accuracy: 0.8619
# Epoch 41/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3402 - accuracy: 0.8605
# Epoch 42/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3391 - accuracy: 0.8608
# Epoch 43/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3394 - accuracy: 0.8620
# Epoch 44/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3388 - accuracy: 0.8610
# Epoch 45/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3388 - accuracy: 0.8612
# Epoch 46/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3383 - accuracy: 0.8618
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3384 - accuracy: 0.8615
# Epoch 48/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3379 - accuracy: 0.8633
# Epoch 49/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3381 - accuracy: 0.8612
# Epoch 50/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3378 - accuracy: 0.8622
# Epoch 51/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3375 - accuracy: 0.8615
# Epoch 52/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3377 - accuracy: 0.8620
# Epoch 53/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3374 - accuracy: 0.8627
# Epoch 54/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3372 - accuracy: 0.8624
# Epoch 55/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3374 - accuracy: 0.8648
# Epoch 56/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3373 - accuracy: 0.8619
# Epoch 57/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3369 - accuracy: 0.8634
# Epoch 58/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3369 - accuracy: 0.8610
# Epoch 59/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3367 - accuracy: 0.8633
# Epoch 60/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3360 - accuracy: 0.8612
# Epoch 61/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3367 - accuracy: 0.8621
# Epoch 62/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3358 - accuracy: 0.8622
# Epoch 63/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3360 - accuracy: 0.8635
# Epoch 64/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3359 - accuracy: 0.8634
# Epoch 65/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3351 - accuracy: 0.8637
# Epoch 66/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3353 - accuracy: 0.8637
# Epoch 67/100
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3355 - accuracy: 0.8616
# Epoch 68/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3349 - accuracy: 0.8631
# Epoch 69/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3353 - accuracy: 0.8616
# Epoch 70/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3349 - accuracy: 0.8629
# Epoch 71/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3346 - accuracy: 0.8636
# Epoch 72/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3342 - accuracy: 0.8648
# Epoch 73/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3346 - accuracy: 0.8631
# Epoch 74/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3341 - accuracy: 0.8633
# Epoch 75/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3340 - accuracy: 0.8626
# Epoch 76/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3343 - accuracy: 0.8652
# Epoch 77/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3336 - accuracy: 0.8640
# Epoch 78/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3338 - accuracy: 0.8634
# Epoch 79/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3335 - accuracy: 0.8641
# Epoch 80/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3328 - accuracy: 0.8636
# Epoch 81/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3333 - accuracy: 0.8649
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3326 - accuracy: 0.8649
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3324 - accuracy: 0.8621
# Epoch 84/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3326 - accuracy: 0.8644
# Epoch 85/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3320 - accuracy: 0.8630
# Epoch 86/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3318 - accuracy: 0.8650
# Epoch 87/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3318 - accuracy: 0.8641
# Epoch 88/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3326 - accuracy: 0.8631
# Epoch 89/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3315 - accuracy: 0.8645
# Epoch 90/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3320 - accuracy: 0.8639
# Epoch 91/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3313 - accuracy: 0.8645
# Epoch 92/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3314 - accuracy: 0.8645
# Epoch 93/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3315 - accuracy: 0.8644
# Epoch 94/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3313 - accuracy: 0.8646
# Epoch 95/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3310 - accuracy: 0.8649
# Epoch 96/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3312 - accuracy: 0.8648
# Epoch 97/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3310 - accuracy: 0.8640
# Epoch 98/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3305 - accuracy: 0.8662
# Epoch 99/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3308 - accuracy: 0.8651
# Epoch 100/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3306 - accuracy: 0.8639

# %%
print(ann.predict(sc.transform([[1 , 0 , 0 , 600 , 1 , 40 , 3 , 60000 , 2 , 1 , 1 ,50000 ]])) > 0.5)
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1,50000]])) > 0.5)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# [[False]]

# %%
ann.save("ANN.hS")

# %%
# Print the number of features in the input data
print(len([[1,0,0,600,1,40,3,60000,2,1,1,50000]]))

# Print the number of features expected by the scaler
print(sc.n_features_in_)
# Out:
# 1
# 13
