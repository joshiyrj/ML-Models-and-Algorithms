# %%
import numpy as np
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
encoding_dim = 32

input_img = Input(shape=(784,))
encoded = Dense(encoding_dim,activation='relu')(input_img)
decoded = Dense(784,activation='sigmoid')(encoded)
autoencoder = Model(input_img, decoded)
encoder = Model(input_img,decoded)
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input,decoder_layer(encoded_input))
autoencoder.compile(optimizer='adadelta',loss='binary_crossentropy')

# %%
(x_train,_),(x_test,_) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
epochs=50,
batch_size=256,
shuffle=True,
validation_data=(x_test, x_test))
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6866 - val_loss: 0.6865
# Epoch 2/50
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6864 - val_loss: 0.6863
# Epoch 3/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6862 - val_loss: 0.6860
# Epoch 4/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6860 - val_loss: 0.6858
# Epoch 5/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6857 - val_loss: 0.6856
# Epoch 6/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6855 - val_loss: 0.6853
# Epoch 7/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6852 - val_loss: 0.6851
# Epoch 8/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6850 - val_loss: 0.6848
# Epoch 9/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6847 - val_loss: 0.6845
# Epoch 10/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6845 - val_loss: 0.6843
# Epoch 11/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6842 - val_loss: 0.6840
# Epoch 12/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6839 - val_loss: 0.6837
# Epoch 13/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6836 - val_loss: 0.6834
# Epoch 14/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6833 - val_loss: 0.6831
# Epoch 15/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6830 - val_loss: 0.6828
# Epoch 16/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6827 - val_loss: 0.6825
# Epoch 17/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6824 - val_loss: 0.6822
# Epoch 18/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6821 - val_loss: 0.6818
# Epoch 19/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6817 - val_loss: 0.6815
# Epoch 20/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6814 - val_loss: 0.6811
# Epoch 21/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6810 - val_loss: 0.6808
# Epoch 22/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6807 - val_loss: 0.6804
# Epoch 23/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.6803 - val_loss: 0.6800
# Epoch 24/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6799 - val_loss: 0.6796
# Epoch 25/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6795 - val_loss: 0.6792
# Epoch 26/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6791 - val_loss: 0.6788
# Epoch 27/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6787 - val_loss: 0.6783
# Epoch 28/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6783 - val_loss: 0.6779
# Epoch 29/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6778 - val_loss: 0.6775
# Epoch 30/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6774 - val_loss: 0.6770
# Epoch 31/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6769 - val_loss: 0.6765
# Epoch 32/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6764 - val_loss: 0.6760
# Epoch 33/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.6759 - val_loss: 0.6755
# Epoch 34/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6754 - val_loss: 0.6750
# Epoch 35/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6749 - val_loss: 0.6744
# Epoch 36/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6743 - val_loss: 0.6739
# Epoch 37/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6738 - val_loss: 0.6733
# Epoch 38/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6732 - val_loss: 0.6727
# Epoch 39/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6726 - val_loss: 0.6721
# Epoch 40/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6720 - val_loss: 0.6715
# Epoch 41/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6714 - val_loss: 0.6708
# Epoch 42/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6707 - val_loss: 0.6702
# Epoch 43/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6701 - val_loss: 0.6695
# Epoch 44/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6694 - val_loss: 0.6688
# Epoch 45/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6687 - val_loss: 0.6681
# Epoch 46/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6680 - val_loss: 0.6673
# Epoch 47/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6672 - val_loss: 0.6666
# Epoch 48/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6665 - val_loss: 0.6658
# Epoch 49/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6657 - val_loss: 0.6650
# Epoch 50/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6649 - val_loss: 0.6642
# 313/313 [==============================] - 1s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e8ab7363188d> in <cell line: 7>()
#       5 validation_data=(x_test, x_test))
#       6 encoded_imgs = encoder.predict(x_test)
# ----> 7 decoded_imgs = decoder.predict(encoded_imgs)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_2" is incompatible with the layer: expected shape=(None, 32), found shape=(None, 784)

# %%
n = 20
plt.figure(figsize=(20,4))
for i in range(n):
  ax = plt.subplot(2,n,i+1)
plt.imshow(x_test[i].reshape(28,28))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.show()

ax = plt.subplot(2,n,i+1+n)
plt.imshow(decoded_imgs[i].reshape(28,28))
plt.gray
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.show()
