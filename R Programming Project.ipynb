# %%
library(tidyverse)
library(MASS)
library(car)
library(e1071)
library(caret)
library(cowplot)
library(caTools)
library(pROC)
library(ggcorrplot)

list.files(path = "../input")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d338af7666e> in <cell line: 1>()
# ----> 1 library(tidyverse)
#       2 library(MASS)
#       3 library(car)
#       4 library(e1071)
#       5 library(caret)
#
# NameError: name 'library' is not defined

# %%
telco <- read.csv("../input/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
glimpse(telco)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a47882a6b57e> in <cell line: 1>()
# ----> 1 glimpse(telco)
#
# NameError: name 'glimpse' is not defined
