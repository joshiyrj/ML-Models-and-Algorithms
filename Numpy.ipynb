# %%
import numpy as np

val_mul = np.array([(3, 4, 2, 5), (3, 6, 2, 4), (1, 5, 2, 6)])
slice_val = val_mul[:2, :2]
print(val_mul[1][1])
# Out:
# 6

# %%
import numpy as np

val_mul = np.array([(3, 4, 2, 5), (3, 6, 2, 4), (1, 5, 2, 6)])
slice_val = val_mul[:2, :2]
print("First 2 rows and columns of the array\n", slice_val)
# Out:
# First 2 rows and columns of the array
#  [[3 4]
#  [3 6]]

# %%
val_mul1=np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6),(1,5,0,1),(7,3,3,0)])
slice_step_row = val_mul1[::2, :2]
print("All rows and 2 columns of the array with step size of 2 along the row\n", slice_step_row)
# Out:
# All rows and 2 columns of the array with step size of 2 along the row
#  [[3 4]
#  [1 5]
#  [7 3]]

# %%
val_mul1=np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6),(1,5,0,1),(7,3,3,0)])

# %%
mul_idx_arr = val_mul1[
    [1,2,2,3],
    [1,2,3,3]
]
print("\nAccesing Elements at multiple indices (1,1),(2,2),(2,3),(3,3)-->", mul_idx_arr)
# Out:
# Accesing Elements at multiple indices (1,1),(2,2),(2,3),(3,3)--> [6 2 6 1]

# %%
condition = val_mul > 3
res = val_mul[condition]
print (res)
# Out:
# [4 5 6 4 5 6]

# %%
val1 = np.array([1,5,2,6])
print(val1.ndim)
# Out:
# 1

# %%
val = np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6)])
print(val)

val = val.reshape(2,6)
print(val)
# Out:
# [[3 4 2 5]
#  [3 6 2 4]
#  [1 5 2 6]]
# [[3 4 2 5 3 6]
#  [2 4 1 5 2 6]]

# %%
print(val.T)
# Out:
# [[3 2]
#  [4 4]
#  [2 1]
#  [5 5]
#  [3 2]
#  [6 6]]

# %%
val = np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6)])
print(val.ravel())
# Out:
# [3 4 2 5 3 6 2 4 1 5 2 6]

# %%
print (val.itemsize)
# Out:
# 8

# %%
print (val.dtype)
# Out:
# int64

# %%
val = np.ones(3)
print(val)

val0=np.zeros(3)
print(val0)
# Out:
# [1. 1. 1.]
# [0. 0. 0.]

# %%
val = np.linspace(2,5,8)
print(val)
# Out:
# [2.         2.42857143 2.85714286 3.28571429 3.71428571 4.14285714
#  4.57142857 5.        ]

# %%
val = np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6)])
print(val.max())
# Out:
# 6

# %%
print(val.min())
# Out:
# 1

# %%
print(val.sum())
# Out:
# 43

# %%
val = np.array([1,4,9])
print(np.sqrt(val))
# Out:
# [1. 2. 3.]

# %%
print(np.std(val))
# Out:
# 3.2998316455372216

# %%
val = np.array([(3,4,2,5),(3,6,2,4),(1,5,2,6)])
print(val+3)
# Out:
# [[6 7 5 8]
#  [6 9 5 7]
#  [4 8 5 9]]

# %%
print(np.sort(val,axis=1))
# Out:
# [[2 3 4 5]
#  [2 3 4 6]
#  [1 2 5 6]]

# %%
print(np.sort(val,axis=0))
# Out:
# [[1 4 2 4]
#  [3 5 2 5]
#  [3 6 2 6]]

# %%
arr = np.array([8,94,8,56,7,3,2,1,0])
print(np.where(arr>10))
# Out:
# (array([1, 3]),)

# %%
np.savetxt('arr_file.csv',arr,delimiter=',')

# %%
np.loadtxt('arr_file.csv',delimiter=',')
# Out:
# array([ 8., 94.,  8., 56.,  7.,  3.,  2.,  1.,  0.])
